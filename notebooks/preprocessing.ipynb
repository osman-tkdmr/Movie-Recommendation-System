# %% [markdown]
# Import libs and funcs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler, LabelEncoder

class EDA:
    def __init__(self, data=None, file_path=None, file_type='csv'):
        self.data = data if data is not None else self.load_data(file_path, file_type) if file_path is not None else pd.DataFrame()
    
    def load_data(self, file_path, file_type='csv'):
        """
        Load data from a file.
        
        Parameters:
            file_path (str): Path to the data file.
            file_type (str): Type of the file ('csv', 'excel', 'json', etc.).
        
        Returns:
            pandas.DataFrame: Loaded data.
        """
        loaders = {
            'csv': pd.read_csv,
            'tsv': lambda path: pd.read_csv(path, sep='\t'),
            'excel': pd.read_excel,
            'json': pd.read_json
        }
        if file_type in loaders:
            return loaders[file_type](file_path)
        else:
            raise ValueError("Unsupported file type.")
    
    def data_types(self):
        """
        Display data types of each column.
        """
        print(self.data.dtypes)
    
    def missing_values(self):
        """
        Summarize missing values in the dataset, showing both count and percentage.
        """
        missing = self.data.isnull().sum()
        total = self.data.shape[0]
        percentage = (missing / total * 100).round(2)
        df_missing = pd.DataFrame({'Missing Count': missing, 'Missing Percentage': percentage}).sort_values(by='Missing Count', ascending=False)
        print("Missing Values Summary:\n", df_missing)
    
    def summary_statistics(self):
        """
        Provide summary statistics of numerical columns.
        """
        print(self.data.describe().T)
    
    def split_columns(self, cat_th=10, car_th=20):
        """
        Splits the columns of the dataset into numerical, categorical, and high cardinality columns.
        
        Parameters:
            cat_th (int, optional): Threshold for unique values to consider a numerical column as categorical.
            car_th (int, optional): Threshold for unique values to consider a categorical column as high cardinality.
        
        Returns:
            cat_cols (list): List of categorical column names.
            num_cols (list): List of numerical column names.
            cat_but_car (list): List of categorical columns with high cardinality.
        """
        cat_cols = [col for col in self.data.columns if self.data[col].dtype == "O"]
        num_cols = [col for col in self.data.columns if self.data[col].dtype != "O"]
        num_but_cat = [col for col in num_cols if self.data[col].nunique() < cat_th]
        cat_but_car = [col for col in cat_cols if self.data[col].nunique() > car_th]
        cat_cols = [col for col in cat_cols if col not in cat_but_car] + num_but_cat
        num_cols = [col for col in num_cols if col not in num_but_cat]
        return cat_cols, num_cols, cat_but_car
    
    def handle_missing_values(self, strategy='drop', column=None, value=None):
        """
        Handle missing values using the specified strategy.
        
        Parameters:
            strategy (str): Strategy to handle missing values ('drop', 'fill').
            column (str): Specific column to handle (for 'fill' strategy).
            value (any): Value to fill missing data (for 'fill' strategy).
        """
        if strategy == 'drop':
            self.data = self.data.dropna(subset=[column]) if column else self.data.dropna()
        elif strategy == 'fill' and column is not None and value is not None:
            self.data[column].fillna(value, inplace=True)
        else:
            raise ValueError("Unsupported strategy or missing parameters for 'fill'.")
    
    def remove_duplicates(self):
        """
        Remove duplicate records from the dataset.
        """
        self.data = self.data.drop_duplicates()
    
    def detect_outliers(self, column):
        """
        Detect outliers in a specified numerical column using IQR.
        
        Parameters:
            column (str): Name of the numerical column
        
        Returns:
            pandas.Series: Boolean series indicating outliers.
        """
        Q1, Q3 = self.data[column].quantile([0.25, 0.75])
        IQR = Q3 - Q1
        lower_fence, upper_fence = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR
        return (self.data[column] < lower_fence) | (self.data[column] > upper_fence)
    
    def plot_histogram(self, column):
        """
        Plot a histogram for a specified numerical column.
        
        Parameters:
            column (str): Name of the numerical column.
        """
        plt.hist(self.data[column], bins=10, edgecolor='black')
        plt.title(f'Histogram of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.show()
    
    def plot_boxplot(self, column):
        """
        Plot a boxplot for a specified numerical column.
        
        Parameters:
            column (str): Name of the numerical column.
        """
        sns.boxplot(x=self.data[column])
        plt.title(f'Boxplot of {column}')
        plt.show()
    
    def plot_correlation_matrix(self):
        """
        Display a correlation matrix heatmap.
        """
        sns.heatmap(self.data.corr(), annot=True, cmap='coolwarm')
        plt.title('Correlation Matrix')
        plt.show()
    
    def calculate_correlation(self, column1, column2):
        """
        Calculate the correlation between two numerical columns.
        
        Parameters:
            column1 (str): Name of the first numerical column.
            column2 (str): Name of the second numerical column.
        
        Returns:
            float: Correlation coefficient.
        """
        return self.data[column1].corr(self.data[column2])
    
    def perform_ttest(self, column, group_by_column):
        """
        Perform a t-test to compare means between groups.
        
        Parameters:
            column (str): Name of the numerical column.
            group_by_column (str): Name of the categorical column to group by.
        
        Returns:
            scipy.stats.ttest_indResult: T-test result.
        """
        groups = self.data[group_by_column].unique()
        if len(groups) != 2:
            raise ValueError("Group by column must have exactly two groups for t-test.")
        group1, group2 = [self.data[self.data[group_by_column] == group][column] for group in groups]
        return stats.ttest_ind(group1, group2)
    
    def scale_data(self, columns):
        """
        Scale specified numerical columns using standard scaling.
        
        Parameters:
            columns (list): List of column names to scale.
        """
        scaler = StandardScaler()
        self.data[columns] = scaler.fit_transform(self.data[columns])
    
    def encode_categorical(self, column):
        """
        Encode a categorical column using one-hot encoding.
        
        Parameters:
            column (str): Name of the categorical column.
        """
        self.data = pd.get_dummies(self.data, columns=[column], drop_first=True)
    
    def save_data(self, file_path, file_type='csv'):
        """
        Save the cleaned data to a specified file path.
        
        Parameters:
            file_path (str): Path to save the file.
            file_type (str): Type of the file ('csv', 'excel', 'json', etc.).
        """
        savers = {
            'csv': self.data.to_csv,
            'excel': self.data.to_excel,
            'json': self.data.to_json
        }
        if file_type in savers:
            savers[file_type](file_path, index=False)
        else:
            raise ValueError("Unsupported file type.")
    
    
    class Visualization:
        def __init__(self, data):
            self.data = data

        def plot_histogram(self, column, bins=10):
            """
            Plot a histogram for a specified numerical column.
            
            Parameters:
                column (str): Name of the numerical column.
                bins (int, optional): Number of bins for the histogram.
            """
            plt.figure(figsize=(10, 6))
            plt.hist(self.data[column], bins=bins, edgecolor='black')
            plt.title(f'Histogram of {column}')
            plt.xlabel(column)
            plt.ylabel('Frequency')
            plt.grid(True)
            plt.show()

        def plot_boxplot(self, column):
            """
            Plot a boxplot for a specified numerical column.
            
            Parameters:
                column (str): Name of the numerical column.
            """
            plt.figure(figsize=(10, 6))
            sns.boxplot(x=self.data[column])
            plt.title(f'Boxplot of {column}')
            plt.grid(True)
            plt.show()

        def plot_correlation_matrix(self):
            """
            Display a correlation matrix heatmap.
            """
            plt.figure(figsize=(12, 8))
            sns.heatmap(self.data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
            plt.title('Correlation Matrix')
            plt.show()

        def plot_scatter(self, column1, column2):
            """
            Plot a scatter plot between two numerical columns.
            
            Parameters:
                column1 (str): Name of the first numerical column.
                column2 (str): Name of the second numerical column.
            """
            plt.figure(figsize=(10, 6))
            plt.scatter(self.data[column1], self.data[column2], alpha=0.7)
            plt.title(f'Scatter Plot of {column1} vs {column2}')
            plt.xlabel(column1)
            plt.ylabel(column2)
            plt.grid(True)
            plt.show()

        def plot_pairplot(self, columns):
            """
            Plot a pairplot for a list of numerical columns.
            
            Parameters:
                columns (list): List of numerical column names.
            """
            sns.pairplot(self.data[columns], diag_kind='kde', plot_kws={'alpha': 0.7})
            plt.show()

class Preprocessing:
    def __init__(self, data):
        self.data = data

    def handle_missing_values(self, strategy='drop', column=None, value=None):
        """
        Handle missing values using the specified strategy.
        
        Parameters:
            strategy (str): Strategy to handle missing values ('drop', 'fill').
            column (str): Specific column to handle (for 'fill' strategy).
            value (any): Value to fill missing data (for 'fill' strategy).
        """
        if strategy == 'drop':
            self.data = self.data.dropna(subset=[column]) if column else self.data.dropna()
        elif strategy == 'fill' and column is not None and value is not None:
            self.data[column].fillna(value, inplace=True)
        else:
            raise ValueError("Unsupported strategy or missing parameters for 'fill'.")

    def remove_duplicates(self):
        """
        Remove duplicate records from the dataset.
        """
        self.data = self.data.drop_duplicates()

    def scale_data(self, columns):
        """
        Scale specified numerical columns using standard scaling.
        
        Parameters:
            columns (list): List of column names to scale.
        """
        scaler = StandardScaler()
        self.data[columns] = scaler.fit_transform(self.data[columns])

    def encode_categorical(self, column):
        """
        Encode a categorical column using one-hot encoding.
        
        Parameters:
            column (str): Name of the categorical column.
        """
        self.data = pd.get_dummies(self.data, columns=[column], drop_first=True)

    def label_encode(self, column):
        """
        Encode a categorical column using label encoding.
        
        Parameters:
            column (str): Name of the categorical column.
        """
        le = LabelEncoder()
        self.data[column] = le.fit_transform(self.data[column])

    def save_data(self, file_path, file_type='csv'):
        """
        Save the cleaned data to a specified file path.
        
        Parameters:
            file_path (str): Path to save the file.
            file_type (str): Type of the file ('csv', 'excel', 'json', etc.).
        """
        savers = {
            'csv': self.data.to_csv,
            'excel': self.data.to_excel,
            'json': self.data.to_json
        }
        if file_type in savers:
            savers[file_type](file_path, index=False)
        else:
            raise ValueError("Unsupported file type.")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler, LabelEncoder

class EDA:
    def __init__(self, data=None, file_path=None, file_type='csv'):
        self.data = data if data is not None else self.load_data(file_path, file_type) if file_path is not None else pd.DataFrame()
    
    def load_data(self, file_path, file_type='csv'):
        loaders = {
            'csv': pd.read_csv,
            'tsv': lambda path: pd.read_csv(path, sep='\t'),
            'excel': pd.read_excel,
            'json': pd.read_json
        }
        if file_type in loaders:
            return loaders[file_type](file_path)
        else:
            raise ValueError("Unsupported file type.")
    
    def data_types(self):
        print(self.data.dtypes)
    
    def missing_values(self):
        missing = self.data.isnull().sum()
        total = self.data.shape[0]
        percentage = (missing / total * 100).round(2)
        df_missing = pd.DataFrame({'Missing Count': missing, 'Missing Percentage': percentage}).sort_values(by='Missing Count', ascending=False)
        print("Missing Values Summary:\n", df_missing)
    
    def summary_statistics(self):
        print(self.data.describe().T)
    
    def split_columns(self, cat_th=10, car_th=20):
        cat_cols = [col for col in self.data.columns if self.data[col].dtype == "O"]
        num_cols = [col for col in self.data.columns if self.data[col].dtype != "O"]
        num_but_cat = [col for col in num_cols if self.data[col].nunique() < cat_th]
        cat_but_car = [col for col in cat_cols if self.data[col].nunique() > car_th]
        cat_cols = [col for col in cat_cols if col not in cat_but_car] + num_but_cat
        num_cols = [col for col in num_cols if col not in num_but_cat]
        return cat_cols, num_cols, cat_but_car
    
    def detect_outliers(self, column):
        Q1, Q3 = self.data[column].quantile([0.25, 0.75])
        IQR = Q3 - Q1
        lower_fence, upper_fence = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR
        return (self.data[column] < lower_fence) | (self.data[column] > upper_fence)
    
    def plot_histogram(self, column):
        plt.hist(self.data[column], bins=10, edgecolor='black')
        plt.title(f'Histogram of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.show()
    
    def plot_boxplot(self, column):
        sns.boxplot(x=self.data[column])
        plt.title(f'Boxplot of {column}')
        plt.show()
    
    def plot_correlation_matrix(self):
        sns.heatmap(self.data.corr(), annot=True, cmap='coolwarm')
        plt.title('Correlation Matrix')
        plt.show()
    
    def calculate_correlation(self, column1, column2):
        return self.data[column1].corr(self.data[column2])
    
    def perform_ttest(self, column, group_by_column):
        groups = self.data[group_by_column].unique()
        if len(groups) != 2:
            raise ValueError("Group by column must have exactly two groups for t-test.")
        group1, group2 = [self.data[self.data[group_by_column] == group][column] for group in groups]
        return stats.ttest_ind(group1, group2)
    
    class Visualization:
        def __init__(self, data):
            self.data = data

        def plot_histogram(self, column, bins=10):
            plt.figure(figsize=(10, 6))
            plt.hist(self.data[column], bins=bins, edgecolor='black')
            plt.title(f'Histogram of {column}')
            plt.xlabel(column)
            plt.ylabel('Frequency')
            plt.grid(True)
            plt.show()

        def plot_boxplot(self, column):
            plt.figure(figsize=(10, 6))
            sns.boxplot(x=self.data[column])
            plt.title(f'Boxplot of {column}')
            plt.grid(True)
            plt.show()

        def plot_correlation_matrix(self):
            plt.figure(figsize=(12, 8))
            sns.heatmap(self.data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
            plt.title('Correlation Matrix')
            plt.show()

        def plot_scatter(self, column1, column2):
            plt.figure(figsize=(10, 6))
            plt.scatter(self.data[column1], self.data[column2], alpha=0.7)
            plt.title(f'Scatter Plot of {column1} vs {column2}')
            plt.xlabel(column1)
            plt.ylabel(column2)
            plt.grid(True)
            plt.show()

        def plot_pairplot(self, columns):
            sns.pairplot(self.data[columns], diag_kind='kde', plot_kws={'alpha': 0.7})
            plt.show()

class Preprocessing:
    def __init__(self, data):
        self.data = data

    def handle_missing_values(self, strategy='drop', column=None, value=None):
        if strategy == 'drop':
            self.data = self.data.dropna(subset=[column]) if column else self.data.dropna()
        elif strategy == 'fill' and column is not None and value is not None:
            self.data[column].fillna(value, inplace=True)
        else:
            raise ValueError("Unsupported strategy or missing parameters for 'fill'.")

    def remove_duplicates(self):
        self.data = self.data.drop_duplicates()

    def scale_data(self, columns):
        scaler = StandardScaler()
        self.data[columns] = scaler.fit_transform(self.data[columns])

    def encode_categorical(self, column):
        self.data = pd.get_dummies(self.data, columns=[column], drop_first=True)

    def label_encode(self, column):
        le = LabelEncoder()
        self.data[column] = le.fit_transform(self.data[column])

    def save_data(self, file_path, file_type='csv'):
        savers = {
            'csv': self.data.to_csv,
            'excel': self.data.to_excel,
            'json': self.data.to_json
        }
        if file_type in savers:
            savers[file_type](file_path, index=False)
        else:
            raise ValueError("Unsupported file type.")

# %%
data = pd.read_csv('../data/raw/TMDB_movie_dataset_v11.csv')

# %%
def custom_info(df):
    info_df = pd.DataFrame({
        'Column': df.columns,
        'Non-Null Count': df.isnull().sum().values,
        'Percent Missing': (df.isnull().sum() / len(df) * 100).values,
        'Dtype': df.dtypes.values,
        'Unique Values': df.nunique().values
    })
    return info_df

# %%
custom_info(data)
# Out:
#                   Column  Non-Null Count  Percent Missing    Dtype  \
# 0                     id               0         0.000000    int64
# 1                  title              13         0.001141   object
# 2           vote_average               0         0.000000  float64
# 3             vote_count               0         0.000000    int64
# 4                 status               0         0.000000   object
# 5           release_date          188032        16.502779   object
# 6                revenue               0         0.000000    int64
# 7                runtime               0         0.000000    int64
# 8                  adult               0         0.000000     bool
# 9          backdrop_path          837192        73.476825   object
# 10                budget               0         0.000000    int64
# 11              homepage         1018772        89.413338   object
# 12               imdb_id          536018        47.044048   object
# 13     original_language               0         0.000000   object
# 14        original_title              13         0.001141   object
# 15              overview          231670        20.332703   object
# 16            popularity               0         0.000000  float64
# 17           poster_path          360017        31.597180   object
# 18               tagline          979686        85.982924   object
# 19                genres          457074        40.115465   object
# 20  production_companies          625499        54.897419   object
# 21  production_countries          505303        44.348321   object
# 22      spoken_languages          486025        42.656372   object
# 23              keywords          831032        72.936187   object
#
#     Unique Values
# 0         1138637
# 1          977192
# 2            5024
# 3            3598
# 4               6
# 5           42742
# 6           14305
# 7             759
# 8               2
# 9          299656
# 10           5723
# 11         113246
# 12         602216
# 13            174
# 14        1011031
# 15         882204
# 16          19888
# 17         774824
# 18         153536
# 19          13344
# 20         206078
# 21          10074
# 22           7058
# 23         176856

# %%
eda = EDA(file_path="../data/raw/TMDB_movie_dataset_v11.csv")

# %%
eda.data.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# 0        Inception  Cobb, a skilled thief who commits corporate es...
# 1     Interstellar  The adventures of a group of explorers who mak...
# 2  The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3           Avatar  In the 22nd century, a paraplegic Marine is di...
# 4     The Avengers  When an unexpected enemy emerges and threatens...
#
#   popularity                       poster_path  \
# 0     83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1    140.241  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2    130.643  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3     79.932  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4     98.082   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...
#
# [5 rows x 24 columns]

# %%
eda.data["release_date"] = pd.to_datetime(eda.data["release_date"])

# %%
cat_cols, num_cols, cat_but_car = eda.split_columns(20, 35)

# %%
print("Categorical Columns:", cat_cols)
print("Numerical Columns:", num_cols)
print("Categorical High Cardinality Columns:", cat_but_car)
# Out:
# Categorical Columns: ['status', 'adult']
# Numerical Columns: ['id', 'vote_average', 'vote_count', 'release_date', 'revenue', 'runtime', 'budget', 'popularity']
# Categorical High Cardinality Columns: ['title', 'backdrop_path', 'homepage', 'imdb_id', 'original_language', 'original_title', 'overview', 'poster_path', 'tagline', 'genres', 'production_companies', 'production_countries', 'spoken_languages', 'keywords']

# %%
spoken_lang_list = eda.data['spoken_languages'].dropna().values
spoken_lang_set = set(lang.strip() for spoken in spoken_lang_list for lang in spoken.split(", ")) # bunu

# %%
list(spoken_lang_set)[:5]
# Out:
# ['Ewe', 'Serbian', 'Tahitian', 'Malay', 'Burmese']

# %%
eda.data["original_language"].unique().tolist()[:5]
# Out:
# ['en', 'ko', 'fr', 'ja', 'it']

# %%
languages = pd.read_csv("../Datasets/iso_639_1codes.csv") # dillerin kısaltmaları ve isimlerini içeren dosya bunu kullanarak dillerin isimlerini alacağız

# %%
languages.head()
# Out:
#   ISO_Code   Language
# 0       aa       Afar
# 1       ab     Abkhaz
# 2       af  Afrikaans
# 3       ak       Akan
# 4       am    Amharic

# %%
lang_map = dict(zip(languages["ISO_Code"], languages["Language"])) 
eda.data["original_language"] = eda.data["original_language"].replace(lang_map) # dillerin kısaltmalarını isimlerine çeviriyoruz

# %%
eda.data["original_language"].unique().tolist()[:5]
# Out:
# ['English', 'Korean', 'French', 'Japanese', 'Italian']

# %% [markdown]
# böyle daha iyi

# %%
eda.missing_values()
# Out:
# Missing Values Summary:n                       Missing Count  Missing Percentage
# homepage                    1018772               89.41
# tagline                      979686               85.98
# backdrop_path                837192               73.48
# keywords                     831032               72.94
# production_companies         625499               54.90
# imdb_id                      536018               47.04
# production_countries         505303               44.35
# spoken_languages             486025               42.66
# genres                       457074               40.12
# poster_path                  360017               31.60
# overview                     231670               20.33
# release_date                 188032               16.50
# date                         188032               16.50
# original_title                   13                0.00
# title                            13                0.00
# id                                0                0.00
# vote_count                        0                0.00
# adult                             0                0.00
# runtime                           0                0.00
# revenue                           0                0.00
# status                            0                0.00
# vote_average                      0                0.00
# popularity                        0                0.00
# budget                            0                0.00
# original_language                 0                0.00

# %% [markdown]
# <br> kolonlarda homepage e kesinlikle ihtiyacımız yok

# %%
eda.data.drop(columns=["homepage"], axis=1, inplace=True)

# %% [markdown]
# <br> title nan ise kaldıracağım zaten 13 satır kaybımız yok

# %%
eda.handle_missing_values('drop', 'title')

# %%
before_filling = eda.data["genres"].isna().sum()

# %%
imdb_data = pd.read_csv("../Datasets/title.basics.tsv", sep="\t") # bunu kullanarak genres sütununu dolduracağız
# Out:
# C:\Users\osman\AppData\Local\Temp\ipykernel_10572\3237295642.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   imdb_data = pd.read_csv("../Datasets/title.basics.tsv", sep="\t")

# %%
imdb_eda = EDA(imdb_data)
imdb_eda.data_types()
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
imdb_eda.data.head()

# %%
# Step 1: Identify rows with missing genres but existing imdb_id
missing_genres = eda.data[(eda.data["genres"].isna()) & (eda.data["imdb_id"].notna())]

# Step 2: Extract imdb_ids that need genre data
imdb_ids_to_fill = missing_genres["imdb_id"].tolist()

# Step 3: Retrieve corresponding genres from imdb_data
key = imdb_data[imdb_data["tconst"].isin(imdb_ids_to_fill)][["tconst", "genres"]]

# Step 4: Merge eda.data with key on imdb_id and tconst
merged_df = eda.data.merge(key, left_on="imdb_id", right_on="tconst", how="left")

# Step 5: Fill missing genres in genres_y with genres_x
merged_df["genres_y"] = merged_df["genres_y"].fillna(merged_df["genres_x"])

# Step 6: Update the original genres column with filled data
eda.data["genres"] = merged_df["genres_y"]

# %%
before_filling - eda.data["genres"].isna().sum()  # genres kolonundan 150459 satır veri kurtardık
# Out:
# np.int64(150467)

# %%
type_key = imdb_eda.data.loc[imdb_data["tconst"].isin(eda.data["imdb_id"]), ["tconst", "titleType"]]
type_key.rename(columns={"tconst": "imdb_id"}, inplace=True)
eda.data = eda.data.merge(type_key, how="left", on="imdb_id")
eda.data["titleType"].value_counts() # bu kolonu da context_data kolonuna ekleyeceğim

# %%
eda.data.shape
# Out:
# (1139383, 24)

# %% [markdown]
# <br> overview, genres, tagline, keywords, production_companies, production_countriesi, spoken_language, original_language, release_date
# <br> kolonlarının birleşiminden combined_features isimli bir kolon oluşturacağım ve nlp ye dayalı modelim bu kolon üzerinde çalışacak

# %%
eda.data["combined_features"] = eda.data["overview"] \
+ " " + eda.data["genres"].fillna("") \
+ " " + eda.data["tagline"].fillna("") \
+ " " + eda.data["keywords"].fillna("") \
+ " " + eda.data["production_companies"].fillna("") \
+ " " + eda.data["production_countries"].fillna("") \
+ " " + eda.data["spoken_languages"].fillna("") \
+ " " + eda.data["original_language"].fillna("") \
+ " " + eda.data["release_date"].fillna("")

# %%
eda.remove_duplicates()

# %%
eda.data.shape
# Out:
# (1139015, 24)

# %%
eda.data[eda.data["genres"].isna() & eda.data["imdb_id"].notna()]
# Out:
#              id                                    title  vote_average  \
# 38983    338418         Nirvana: Smells Like Teen Spirit         7.400
# 67007    193806                      Thanksgiving Prayer         6.400
# 73788    919999                        Remember the Time         7.545
# 85160    338289  Twisted Sister: We're Not Gonna Take It         7.100
# 85988    204745                      Falling for Scratte         5.600
# ...         ...                                      ...           ...
# 1132604  744439                           The Other Side         0.000
# 1136642  735537                     Abudu: Lieju Kartybę         0.000
# 1136977  735663                             Static Shock         0.000
# 1137056  737537                                  Marsden         0.000
# 1138458  733389                                     国产电影         0.000
#
#          vote_count         status release_date  revenue  runtime  adult  \
# 38983            29       Released   1991-01-01        0        0  False
# 67007            12       Released   1991-01-01        0        2  False
# 73788            11       Released   1992-02-02        0        9  False
# 85160             8       Released   1984-01-01        0        0  False
# 85988             8       Released   2009-10-27        0        9  False
# ...             ...            ...          ...      ...      ...    ...
# 1132604           0       Released          NaN        0       13  False
# 1136642           0       Released   2020-03-09        0        4  False
# 1136977           0        Planned          NaN        0        0  False
# 1137056           0  In Production          NaN        0       12  False
# 1138458           0       Released          NaN     6000        0  False
#
#          budget  ... popularity                       poster_path  \
# 38983         0  ...      2.468  /84PnF5DC9HMVRSNDm36uhekOfyZ.jpg
# 67007         0  ...      0.605  /bt1K9xTOmBR6gs7BTC1ycVzE6CQ.jpg
# 73788         0  ...      1.205  /oa2iI6ZVPXd2Oh3zyEcVuzPomUU.jpg
# 85160         0  ...      0.600                               NaN
# 85988         0  ...      1.832  /1sUk97R91ycRUV1ZzGHscWUHusq.jpg
# ...         ...  ...        ...                               ...
# 1132604       0  ...      0.600                               NaN
# 1136642       0  ...      0.600  /biGyVrI1sa22MxQubf6rH45Kf3F.jpg
# 1136977       0  ...      0.625  /uoQNLBmhbs56YdOv7EJi77CTeVj.jpg
# 1137056       0  ...      0.600  /5pmkWsC6bMosC3nbBoCtXI0ZeFV.jpg
# 1138458    5000  ...      0.600                               NaN
#
#                                         tagline genres  \
# 38983                                       NaN    NaN
# 67007                                       NaN    NaN
# 73788                                       NaN    NaN
# 85160                                       NaN    NaN
# 85988                                       NaN    NaN
# ...                                         ...    ...
# 1132604                                     NaN    NaN
# 1136642                                     NaN    NaN
# 1136977                                     NaN    NaN
# 1137056  WHAT DOES IT TAKE TO PULL THE TRIGGER?    NaN
# 1138458                                     NaN    NaN
#
#                                  production_companies  \
# 38983                                             NaN
# 67007                                             NaN
# 73788                                             NaN
# 85160                                             NaN
# 85988                                Blue Sky Studios
# ...                                               ...
# 1132604                                           NaN
# 1136642                                           NaN
# 1136977  Outlier Society Productions, Milestone Media
# 1137056                                           NaN
# 1138458                                           NaN
#
#              production_countries spoken_languages  \
# 38983                         NaN              NaN
# 67007    United States of America          English
# 73788    United States of America              NaN
# 85160                         NaN              NaN
# 85988    United States of America          English
# ...                           ...              ...
# 1132604                       NaN              NaN
# 1136642                       NaN              NaN
# 1136977  United States of America          English
# 1137056                       NaN              NaN
# 1138458                       NaN              NaN
#
#                                            keywords titleType  \
# 38983                                           NaN       NaN
# 67007    politics, poetry, thanksgiving, short film       NaN
# 73788                                           NaN       NaN
# 85160                                           NaN       NaN
# 85988                                           NaN       NaN
# ...                                             ...       ...
# 1132604                                         NaN       NaN
# 1136642                                         NaN       NaN
# 1136977                                         NaN       NaN
# 1137056                                         NaN       NaN
# 1138458                                         NaN       NaN
#
#                                          combined_features
# 38983                                                  NaN
# 67007    An indictment ballad of all the different poli...
# 73788    The second short film produced for Michael Jac...
# 85160                                                  NaN
# 85988    A behind the scenes video about Scrat and Scra...
# ...                                                    ...
# 1132604  A detective interrogates Monroe, a suspect in ...
# 1136642  Life's moments need to be let out.       Engli...
# 1136977  A feature film based on the DC superhero.    O...
# 1137056  To his employers, Marsden is a reliable and ru...
# 1138458                                                NaN
#
# [747 rows x 24 columns]

# %%
eda.missing_values()
# Out:
# Missing Values Summary:
#                        Missing Count  Missing Percentage
# tagline                      979348               85.98
# keywords                     830735               72.93
# production_companies         625219               54.89
# titleType                    537832               47.22
# imdb_id                      535744               47.04
# production_countries         505011               44.34
# spoken_languages             485742               42.65
# poster_path                  352858               30.98
# genres                       306404               26.90
# overview                     231550               20.33
# combined_features            231550               20.33
# release_date                 187808               16.49
# title                             0                0.00
# vote_average                      0                0.00
# id                                0                0.00
# vote_count                        0                0.00
# runtime                           0                0.00
# revenue                           0                0.00
# status                            0                0.00
# popularity                        0                0.00
# adult                             0                0.00
# original_title                    0                0.00
# budget                            0                0.00
# original_language                 0                0.00

# %%
eda.data[eda.data["poster_path"].isna() & eda.data["backdrop_path"].notna()].shape
# Out:
# (6922, 24)

# %% [markdown]
# <br> poster yerine backdrop resmini kullanabileceğim yaklaşık 7 bin veri var
# <br> uygulamamda sadece poster resmini kullanacağım için backdrop tan ihtiyacım olan eksik verileri çekip backdropu kaldıracağım

# %%
mask = eda.data["poster_path"].isna() & eda.data["backdrop_path"].notna()
eda.data["poster_path"] = eda.data["poster_path"].mask(mask, eda.data["backdrop_path"])
eda.data.drop(columns=["backdrop_path"], axis=1,inplace=True)
